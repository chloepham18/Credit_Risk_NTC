# %% [markdown]
# # 📊 NTC Consumer Credit: Credit Risk Modeling for New-To-Credit (NTC) Customers
#
# This project focuses on building a credit risk model for New-To-Credit (NTC) customers to predict the likelihood of charge-offs, enabling financial institutions to make informed, risk-based decisions when approving credit applications. The model prioritizes **precision** (0.667 on validation) to support growth while minimizing default rates.
#
# ---
#
# ## 🔍 Project Overview
#
# - **Goal**: Assess credit risk for NTC customers and develop a risk-based underwriting strategy.
# - **Target**: Predict `Ever_ChargeOff` (binary) using a Random Forest Classifier.
# - **Focus**: High precision (threshold 0.7) to minimize false approvals of risky customers.
# - **Key Metrics**:
#   - Precision: 0.667 (Validation), 0.53 (Test)
#   - AUC: 0.953 (Validation), 0.94 (Test)
#
# ---
#
# ## 📈 Data Analysis: NTC Customer Profiles
#
# The dataset was analyzed across multiple dimensions: FICO scores, asset bands, debt-to-income (DTI) ratios, loan amounts, and credit utilization. Below is a summary of the key insights from the data distribution.
#
# ### 1. FICO x Asset Distribution
# | FICO Band | <500 | 501-1000 | 1001-1500 | 1501-2000 | 2001-2500 | >3K | Grand Total |
# |-----------|------|----------|-----------|-----------|-----------|------|-------------|
# | <520      | 29.41% | 22.73% | 15.79% | 18.75% | 14.29% | 15.00% | 19.44% |
# | 520-569   | 18.18% | 17.95% | 5.17% | 18.00% | 11.11% | 19.61% | 14.75% |
# | 570-599   | 11.76% | 15.00% | 25.00% | 22.22% | 14.81% | 18.52% | 18.37% |
# | 600-639   | 10.00% | 19.35% | 28.95% | 12.50% | 16.22% | 8.11% | 16.10% |
# | 640+      | 18.32% | 11.59% | 17.24% | 10.81% | 10.69% | 6.21% | 12.38% |
#
# - **Insight**: FICO 640+ (12.38%) with assets $501-1500 (11.59%-17.24%) shows lower risk. FICO <520 (19.44%) with assets <500 (29.41%) is high-risk.
#
# ### 2. FICO x DTI Distribution
# | FICO Band | <1%   | 1-3%  | 3-5%  | 5-7%  | 7-10% | Grand Total |
# |-----------|-------|-------|-------|-------|-------|-------------|
# | <520      | 12.50% | 24.07% | 25.00% | 0.00% | 0.00% | 19.44% |
# | 520-569   | 20.21% | 8.33% | 0.00% | 33.33% | 0.00% | 14.75% |
# | 570-599   | 16.67% | 20.48% | 0.00% | 0.00% | 0.00% | 18.37% |
# | 600-639   | 18.72% | 12.87% | 0.00% | 50.00% | 28.57% | 16.10% |
# | 640+      | 13.17% | 12.87% | 29.41% | 0.00% | 0.00% | 12.38% |
#
# - **Insight**: DTI <1% (15.31%) in FICO 640+ (13.17%) indicates low risk. High DTI (7-10%) in FICO 600-639 (28.57%) is riskier.
#
# ### 3. Asset x Loan Amount Distribution
# | Asset Band | No Debt (<10K) | Moderate (5K-10K) | High (10K-25K) | Grand Total |
# |------------|----------------|-------------------|----------------|-------------|
# | <500       | 18.88% | 19.23% | 15.73% | 17.57% |
# | 501-1000   | 13.55% | 11.11% | 14.69% | 14.49% |
# | 1001-1500  | 18.95% | 14.29% | 16.83% | 16.83% |
# | 1501-2000  | 14.38% | 16.67% | 14.18% | 14.18% |
# | 2001-2500  | 8.28% | 23.08% | 14.08% | 12.09% |
# | >3K        | 10.75% | 13.16% | 10.47% | 10.47% |
#
# - **Insight**: Asset $501-1500 with loan amount <10K (18.95%) is a stable segment. High loans (>10K-25K) in asset <500 (15.73%) are riskier.
#
# ### 4. FICO x Utilization Distribution
# | FICO Band | Very Low (<10%) | Low (10-30%) | Moderate (30-60%) | High (60-100%) | Grand Total |
# |-----------|-----------------|--------------|-------------------|----------------|-------------|
# | <520      | 9.09% | 14.29% | 31.58% | 16.67% | 19.44% |
# | 520-569   | 8.33% | 15.63% | 20.00% | 14.75% | 14.75% |
# | 570-599   | 9.38% | 20.37% | 22.22% | 18.37% | 18.37% |
# | 600-639   | 11.11% | 15.49% | 15.49% | 16.10% | 16.10% |
# | 640+      | 15.45% | 10.66% | 10.66% | 12.38% | 12.38% |
#
# - **Insight**: FICO 640+ with utilization <10% (15.45%) is low-risk. High utilization (60-100%) in FICO <520 (50.00%) indicates overextension.
#
# ---
#
# ## 💡 Recommendations for NTC Customer Approvals
#
# Based on the analysis and the model’s precision-focused strategy (threshold 0.7), we recommend approving NTC customers with the following profiles:
#
# - **FICO Score 600+ (preferably 640+)**: These customers (12.38% in 640+) are lower risk, especially with assets in the $501-1500 range.
# - **Asset Band $501-1500**: This range (14.49%-16.83%) indicates financial stability.
# - **DTI <3%**: Customers with DTI <1% (15.31%) or 1-3% (14.24%) in FICO 640+ or asset band $501-1500 are low-risk.
# - **Loan Amount <10K**: Approve customers with loans <10K (14.20%), especially in FICO 640+ (13.11%) or asset band $501-1500 (18.88%).
# - **Utilization <30%**: Very low (<10%) or low (10-30%) utilization in FICO 640+ (15.45%) or asset band $501-1500 (16.47%) indicates responsible credit use.
#
# ### Profiles to Avoid:
# - **FICO <520**: High risk (19.44%), especially with assets <500 (29.41%) or high utilization (50.00%).
# - **High DTI (7-10%)**: Particularly in FICO <520 or asset band <500 (22.47%).
# - **High Loan Amounts (>10K-25K)**: Risky in FICO <520 (24.14%) or asset band <500 (15.73%).
# - **High Utilization (60-100%)**: Avoid in FICO <520 (50.00%) or asset band <500 (17.57%).
